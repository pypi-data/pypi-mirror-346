# %%
import pyslammer as slam

# %%
asdf = slam.find_harmonic_solution(1, 0.6, grav=9.81, plot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 asdf = slam.find_harmonic_solution(1, 0.6, grav=9.81, plot=True)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
