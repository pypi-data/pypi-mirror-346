# %% [markdown]
# # Scraping Sentenze Appalti

# %%
# %pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\burre\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\burre\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\burre\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\burre\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\burre\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\burre\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\burre\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4) (2.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\burre\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importiamo le librerie

# %%
import os
import re
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Definiamo le principali funzioni per lo scraping delle pagine di SentenzeAppalti

# %%
# Base URL of the website
base_url = 'https://www.sentenzeappalti.it/'

# Function to scrape articles within the specified structure
def get_article_tags_and_links(page_url):
    try:
        # Send request to the page
        response = requests.get(page_url)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')

        main_content = soup.find('div', id='main-content')

        primary_content = main_content.find('div', id='primary')

        content_area = primary_content.find('div', id='content')

        articles = content_area.find_all('article')

        # Extract article links and associated tags
        relevant_articles = []
        for article in articles:
            title = article.find('h1')
            article_url = title.find('a')['href']

            pattern = r'\b\w*d[\-\.]?lgs[\-\.]?\s*36[\-\.]?\/[\-\.]?2023\w*\b'

            if re.search(pattern, article.get_text()):
                tag_links_span = article.find('span', class_='tag-links')
                if tag_links_span:
                    link_tags = [a['href'] for a in tag_links_span.find_all('a', href=True) if "36-2023" in a['href']]
                else:
                    link_tags = []

                relevant_articles.append({
                    'url': article_url,    # URL of the article
                    'tags': article['class'],  # Article classes as tag proxies
                    'link_tags': link_tags     # List of extracted links (or empty)
                })

        return relevant_articles

    except Exception as e:
        print(f"Error scraping {page_url}: {e}")
        return []

# Download the article from the URL provided
def download_article(url):
    try:
        # Create download directory on the Desktop
        download_dir = os.path.join(os.path.expanduser("~/Desktop"), 'downloaded_articles_sentenzeAppalti')
        os.makedirs(download_dir, exist_ok=True)

        # Make the request to the URL
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        article = soup.find('article')
        entry_content = article.find('div', class_='entry-content')

        if entry_content:
            # Extract text from all <p> elements
            article_content = '\n'.join(p.get_text().replace('\n', ' ') for p in entry_content.find_all('p'))
            base_file_name = url.split('/')[-2]  # Get the base name from the URL
            file_name = f"{base_file_name}.txt"
            file_path = os.path.join(download_dir, file_name)

            # Check if the file already exists
            counter = 1
            while os.path.exists(file_path):
                file_name = f"{base_file_name}_{counter}.txt"
                file_path = os.path.join(download_dir, file_name)
                counter += 1

            # Save the article content to a file
            with open(file_path, 'w', encoding='utf-8') as file:
                file.write(article_content)
            print(f"Downloaded and saved: {file_path}")
        else:
            print(f"Div with class 'entry-content' not found for {url}.")
    except requests.HTTPError as http_err:
        print(f"HTTP error occurred while downloading {url}: {http_err}")
    except requests.RequestException as req_err:
        print(f"Request error occurred while downloading {url}: {req_err}")
    except Exception as e:
        print(f"Error downloading {url}: {e}")

# Main function to scrape the homepage and subsequent pages for relevant articles
def scrape_articles():
    documents = []

    # Start with the homepage or first page
    current_page = base_url
    for page_number in range(1, 5):  # Adjust page range as needed
        print(f"Scraping page {page_number}...")
        articles = get_article_tags_and_links(current_page)
        documents.extend(articles)
        current_page = f'{base_url}page/{page_number}/'

    return documents

# %% [markdown]
# ### Eseguiamo lo scraping di sentenzeAppalti riguardante gli articoli con tag "36-2023"

# %%
# Run the scraper and print results
articles = scrape_articles()
for article in articles:
    download_article(article['url'])
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\incentivi-funzioni-tecniche-calcolo-sull-importo-a-base-delle-procedure-al-netto-delle-eventuali-opzioni.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\rotazione-gestore-uscente-nuovamente-affidatario-in-raggruppamento-temporaneo-con-altri-operator-economici.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\affidamento-diretto-sopra-5-000-euro-ed-obbligo-utilizzo-mepa-equivalente-la-piattaforma-approvvigionamento-digitale-pad-della-stazione-appaltante.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\riesame-delle-offerte-da-parte-della-commissione-giudicatrice-quando-e-consentita.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\attivita-incentivabili-per-i-lavori-pubblici.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\opzione-contrattuale-variante-e-quinto-d-obbligo-differenze-e-presupposti.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\avvalimento-premiale-e-possesso-requisiti-speciali-da-parte-dell-impresa-ausiliaria.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\calcolo-importo-a-base-asta-e-costo-della-manodopera-in-assenza-di-tabelle-ministeriali.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\progetto-di-riassorbimento-del-personale-omessa-produzione-soccorso-istruttorio-non-applicabile-art-102-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\incentivi-funzioni-tecniche-calcolo-sull-importo-a-base-delle-procedure-al-netto-delle-eventuali-opzioni_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\rotazione-gestore-uscente-nuovamente-affidatario-in-raggruppamento-temporaneo-con-altri-operator-economici_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\affidamento-diretto-sopra-5-000-euro-ed-obbligo-utilizzo-mepa-equivalente-la-piattaforma-approvvigionamento-digitale-pad-della-stazione-appaltante_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\riesame-delle-offerte-da-parte-della-commissione-giudicatrice-quando-e-consentita_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\attivita-incentivabili-per-i-lavori-pubblici_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\opzione-contrattuale-variante-e-quinto-d-obbligo-differenze-e-presupposti_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\avvalimento-premiale-e-possesso-requisiti-speciali-da-parte-dell-impresa-ausiliaria_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\calcolo-importo-a-base-asta-e-costo-della-manodopera-in-assenza-di-tabelle-ministeriali_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\progetto-di-riassorbimento-del-personale-omessa-produzione-soccorso-istruttorio-non-applicabile-art-102-d-lgs-36-2023_1.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\ribasso-indiretto-dei-costi-della-manodopera-art-41-art-110-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\esclusione-sulla-base-della-teoria-del-contagio.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\unico-centro-decisionale-ed-onere-della-prova-contraria-art-95-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\contributo-anac-omesso-pagamento-esclusione-illegittimita-art-10-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\affidamento-diretto-necessaria-indicazione-costi-della-manodopera.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\equo-compenso-nei-servizi-di-progettazione-indirizzo-consolidato-in-attesa-del-correttivo.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\avvalimento-di-garanzia-nel-nuovo-art-104-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\requisito-della-distanza-rispetto-alla-sede-della-stazione-appaltante-limiti-art-108-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\subappalto-della-relazione-geologica-nel-d-lgs-36-2023-soltanto-se-affidatario-e-in-possesso-dei-requisiti-minimi.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\dichiarazione-sul-possesso-dei-requisiti-inammissibile-il-soccorso-istruttorio-integrativo-o-modificativo.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\servizi-progettazione-equo-compenso-non-applicabile-alle-procedure-di-gara-regolate-dal-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\accesso-agli-atti-decisioni-sulle-richieste-di-oscuramento-delle-offerte-e-termine-decadenziale-per-il-ricorso.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\sicurezza-sul-lavoro-obblighi-e-doveri-in-caso-di-appalto-pubblico.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\requisiti-di-esecuzione-il-possesso-rileva-esclusivamente-nella-fase-della-stipulazione-del-contratto-non-in-fase-di-valutazione-delle-offerte-art-113-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\sopralluogo-termine-a-pena-di-esclusione-illegittimita-art-92-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\chiarimenti-sul-principio-di-equivalenza-e-sulla-nozione-di-conformita-sostanziale.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\applicazione-dei-contratti-collettivi-nazionali-di-settore-e-liberta-dell-imprenditore-art-11-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\accesso-termine-di-impugnazione-nel-d-lgs-36-2023-coincide-con-quello-in-cui-il-concorrente-acquisisce-o-e-messo-in-grado-di-acquisire-piena-conoscenza-degli-atti-di-gara-art-36-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\contratto-di-avvalimento-non-modificabile-dopo-il-termine-di-scadenza-delle-offerte-soccorso-istruttorio.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\soccorso-istruttorio-processuale-per-offerta-tecnica-limiti.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\subappalto-integrale-risultante-dai-preventivi-dei-subappaltatori-in-sede-di-anomalia-esclusione-art-110-art-119-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\subappalto-necessario-e-categorie-scorporabili-a-qualificazione-obbligatoria-nel-nuovo-codice-art-100-allegato-ii-12-d-lgs-36-2023.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\costi-della-manodopera-ribasso-soltanto-indiretto.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\rinvio-a-giudizio-necessario-il-contraddittorio-procedimentale-ai-fini-dell-esclusione.txt
# Downloaded and saved: C:\Users\burre/Desktop\downloaded_articles_sentenzeAppalti\accesso-agli-atti-quando-il-diritto-alla-difesa-in-giudizio-prevale-sui-segreti-tecnici-o-commerciali.txt
