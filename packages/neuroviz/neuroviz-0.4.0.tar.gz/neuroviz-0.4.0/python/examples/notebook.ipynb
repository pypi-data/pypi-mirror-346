# %%
from neuroviz import NeuroViz, ParameterDict, default_parameters

# %%
neuro = NeuroViz(port=9001, use_secret=False)
# Out:
# Starting server on port 9001
# Connect glasses using QR code:
#
#    ▄▄▄▄▄  ▄      ▄  ▄▄▄ ▄▄   ▄▄▄▄▄
#           ▄    ▄▄  ▄▄ ▄▄
#     ▄▄▄     ▄     ▄ ▄▄ ▄ ▄    ▄▄▄
#   ▄▄▄▄▄▄▄  ▄ ▄  ▄▄ ▄ ▄▄▄ ▄  ▄▄▄▄▄▄▄
#         ▄ ▄  ▄ ▄ ▄   ▄▄▄▄▄  ▄▄▄▄▄▄
#   ▄  ▄▄ ▄▄▄▄▄▄  ▄▄   ▄▄   ▄▄▄    ▄
#   ▄ ▄▄▄▄▄ ▄  ▄▄ ▄ ▄    ▄   ▄▄ ▄▄▄ ▄
#    ▄▄▄▄▄▄▄  ▄     ▄▄    ▄        ▄▄
#   ▄▄▄   ▄▄ ▄▄▄       ▄ ▄ ▄▄ ▄▄▄▄ ▄▄
#   ▄ ▄▄▄▄▄  ▄▄ ▄ ▄▄  ▄  ▄ ▄    ▄▄▄
#   ▄    ▄▄▄▄▄   ▄▄▄▄▄▄▄▄▄▄▄▄▄▄ ▄▄▄▄▄
#     ▄▄▄ ▄ ▄▄  ▄   ▄ ▄▄▄▄▄▄  ▄▄▄   ▄
#   ▄▄▄▄  ▄ ▄▄ ▄▄ ▄▄▄▄  ▄ ▄▄ ▄▄▄ ▄▄ ▄
#    ▄▄▄▄▄  ▄▄ ▄▄     ▄  ▄▄▄  ▄
#           ▄ ▄ ▄▄▄ ▄ ▄▄▄▄▄▄   ▄ ▄▄▄
#     ▄▄▄      ▄ ▄  ▄  ▄  ▄▄▄▄▄   ▄
#   ▄▄▄▄▄▄▄ ▄▄ ▄▄  ▄▄▄   ▄ ▄▄       ▄

# %%
default_parameters()
# Out:
# {'transparency': 0.0,
#  'glow': 0.0,
#  'smoothness': 0.5,
#  'emission': 0.0,
#  'light_intensity': 1.0,
#  'light_temperature': 6500.0}

# %%
neuro.set_live_parameters({
  'transparency': 0.5,
  'glow': 0.0,
  'smoothness': 0.5,
  'emission': 0.0,
  'light_intensity': 1.0,
  'light_temperature': 6500.0
})

# %%
a: ParameterDict = {
  **default_parameters(),
  'transparency': 1.0,
}

b = {
  **default_parameters(),
  'transparency': 0.5,
}

chosen = neuro.prompt_choice(a, b)
print(chosen)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       1 a: ParameterDict = {
#       2   **default_parameters(),
#       3   'transparency': 1.0,
#       4 }
#       6 b = {
#       7   **default_parameters(),
#       8   'transparency': 0.5,
#       9 }
# ---> 11 chosen = neuro.prompt_choice(a, b)
#      12 print(chosen)
#
# KeyboardInterrupt:

# %%
a: ParameterDict = {
  **default_parameters(),
  'glow': 1.0,
}

rating = chosen = neuro.prompt_rating(a)
print(rating)
# Out:
# 2
